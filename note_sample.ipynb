# %%
# !pip install altair
# !pip install vega_datasets
# Out:
# WARNING: The directory '/Users/admin/Library/Caches/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# Collecting altair
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#      |████████████████████████████████| 812 kB 4.3 MB/s eta 0:00:01
# Collecting toolz
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 38.3 MB/s eta 0:00:01
# Requirement already satisfied: entrypoints in ./venv/lib/python3.10/site-packages (from altair) (0.4)
# Collecting pandas>=0.18
#   Downloading pandas-1.4.3-cp310-cp310-macosx_11_0_arm64.whl (10.4 MB)
#      |████████████████████████████████| 10.4 MB 2.9 MB/s eta 0:00:01    |█████████████████████▍          | 6.9 MB 3.4 MB/s eta 0:00:02
# Requirement already satisfied: jsonschema>=3.0 in ./venv/lib/python3.10/site-packages (from altair) (4.4.0)
# Collecting numpy
#   Downloading numpy-1.23.1-cp310-cp310-macosx_11_0_arm64.whl (13.3 MB)
#      |████████████████████████████████| 13.3 MB 3.5 MB/s eta 0:00:01
# Requirement already satisfied: jinja2 in ./venv/lib/python3.10/site-packages (from altair) (3.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./venv/lib/python3.10/site-packages (from jsonschema>=3.0->altair) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in ./venv/lib/python3.10/site-packages (from jsonschema>=3.0->altair) (21.4.0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.10/site-packages (from pandas>=0.18->altair) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./venv/lib/python3.10/site-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.10/site-packages (from jinja2->altair) (2.1.1)
# Installing collected packages: numpy, toolz, pandas, altair
# Successfully installed altair-4.2.0 numpy-1.23.1 pandas-1.4.3 toolz-0.12.0
# WARNING: You are using pip version 21.1.2; however, version 22.1.2 is available.
# You should consider upgrading via the '/Users/admin/Git/Public/elixirnote/venv/bin/python -m pip install --upgrade pip' command.
# WARNING: The directory '/Users/admin/Library/Caches/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# Collecting vega_datasets
#   Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 4.6 MB/s eta 0:00:01
# Requirement already satisfied: pandas in ./venv/lib/python3.10/site-packages (from vega_datasets) (1.4.3)
# Requirement already satisfied: numpy>=1.21.0 in ./venv/lib/python3.10/site-packages (from pandas->vega_datasets) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./venv/lib/python3.10/site-packages (from pandas->vega_datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.10/site-packages (from pandas->vega_datasets) (2022.1)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->vega_datasets) (1.16.0)
# Installing collected packages: vega-datasets
# Successfully installed vega-datasets-0.9.0
# WARNING: You are using pip version 21.1.2; however, version 22.1.2 is available.
# You should consider upgrading via the '/Users/admin/Git/Public/elixirnote/venv/bin/python -m pip install --upgrade pip' command.

# %%
# Multi-panel Scatter Plot with Linked Brushing

# %%
import altair as alt
from vega_datasets import data

source = data.cars()

brush = alt.selection(type='interval', resolve='global')

base = alt.Chart(source).mark_point().encode(
    y='Miles_per_Gallon',
    color=alt.condition(brush, 'Origin', alt.ColorValue('gray')),
).add_selection(
    brush
).properties(
    width=250,
    height=250
)

base.encode(x='Horsepower') | base.encode(x='Acceleration')
# Out:
# alt.HConcatChart(...)

# %%
import altair as alt
from vega_datasets import data

source = data.stocks()

alt.Chart(source).mark_line(point=True).encode(
    x='date:T',
    y='price:Q',
    color='symbol:N'
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
from vega_datasets import data

source = data.seattle_weather()

# Size of the hexbins
size = 15
# Count of distinct x features
xFeaturesCount = 12
# Count of distinct y features
yFeaturesCount = 7
# Name of the x field
xField = 'date'
# Name of the y field
yField = 'date'

# the shape of a hexagon
hexagon = "M0,-2.3094010768L2,-1.1547005384 2,1.1547005384 0,2.3094010768 -2,1.1547005384 -2,-1.1547005384Z"

alt.Chart(source).mark_point(size=size**2, shape=hexagon).encode(
    x=alt.X('xFeaturePos:Q', axis=alt.Axis(title='Month',
                                           grid=False, tickOpacity=0, domainOpacity=0)),
    y=alt.Y('day(' + yField + '):O', axis=alt.Axis(title='Weekday',
                                                   labelPadding=20, tickOpacity=0, domainOpacity=0)),
    stroke=alt.value('black'),
    strokeWidth=alt.value(0.2),
    fill=alt.Color('mean(temp_max):Q', scale=alt.Scale(scheme='darkblue')),
    tooltip=['month(' + xField + '):O', 'day(' + yField + '):O', 'mean(temp_max):Q']
).transform_calculate(
    # This field is required for the hexagonal X-Offset
    xFeaturePos='(day(datum.' + yField + ') % 2) / 2 + month(datum.' + xField + ')'
).properties(
    # Exact scaling factors to make the hexbins fit
    width=size * xFeaturesCount * 2,
    height=size * yFeaturesCount * 1.7320508076,  # 1.7320508076 is approx. sin(60°)*2
).configure_view(
    strokeWidth=0
)

# %%
import altair as alt
from vega_datasets import data

# Since the data is more than 5,000 rows we'll import it from a URL
source = data.zipcodes.url

alt.Chart(source).transform_calculate(
    "leading digit", alt.expr.substring(alt.datum.zip_code, 0, 1)
).mark_circle(size=3).encode(
    longitude='longitude:Q',
    latitude='latitude:Q',
    color='leading digit:N',
    tooltip='zip_code:N'
).project(
    type='albersUsa'
).properties(
    width=950,
    height=700
)
# Out:
# alt.Chart(...)
